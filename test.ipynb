# %%
import pandas as pd
df=pd.read_csv("cleaned_df.csv")
df
# Out:
#       Unnamed: 0    Country                     Zone                   Region  \
# 0              0      India                  Western                  Gujarat
# 1              1      India                 Northern                    Delhi
# 2              2      India                  Eastern                    Bihar
# 3              3      India            North-Eastern                    Assam
# 4              4      India                 Northern                Rajasthan
# ...          ...        ...                      ...                      ...
# 9854        9854  Sri Lanka             Uva Province             Uva Province
# 9855        9855  Sri Lanka             Sabaragamuwa             Sabaragamuwa
# 9856        9856  Sri Lanka         Western Province         Western Province
# 9857        9857  Sri Lanka         Eastern Province         Eastern Province
# 9858        9858  Sri Lanka   North Western Province   North Western Province
#
# ...
